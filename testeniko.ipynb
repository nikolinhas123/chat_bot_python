# %%
print ("olá world")



from tkinter import*
import random
# Out:
# olá world

# %%
from chatterbot.trainers import listTrainer
from chatterbot import chatbot
import time

time.clock = time.time
bot = chatbot('chatbot')

trainer = listTrainer(bot)
trainer.train(conversa)
pergunta = ###texto da interface do usuario
resposta = bot.get_response(pergunta)
taxa_acerto = resposta.confidence*100



# Vetor de perguntas
perguntas = [
    "Qual é a capital do Brasil?",
    "Quem escreveu 'Dom Quixote'?",
    "Qual é o maior planeta do sistema solar?",
    "Quem pintou a Mona Lisa?",
    "Qual é o rio mais longo do mundo?",
    "Quem foi o primeiro presidente dos Estados Unidos?",
    "Quem é o criador do Facebook?",
    "Qual é a fórmula química da água?",
    "Qual é o animal terrestre mais rápido?",
    "Qual é a montanha mais alta do mundo?",
    "Quantos elementos químicos naturais existem?",
    "Qual é o maior oceano do mundo?",
    "Quem escreveu 'Romeu e Julieta'?",
    "Qual é a velocidade da luz?",
    "Quem foi o primeiro homem a pisar na Lua?",
    "Quem foi o primeiro imperador romano?",
    "Qual é o maior deserto do mundo?",
    "Qual é o número atômico do hidrogênio?",
    "Quem foi o inventor da lâmpada elétrica?",
    "Qual é o país mais populoso do mundo?"
]

# Vetor de respostas
respostas = [
    "Brasília",
    "Miguel de Cervantes",
    "Júpiter",
    "Leonardo da Vinci",
    "Rio Nilo",
    "George Washington",
    "Mark Zuckerberg",
    "H2O",
    "Guepardo",
    "Monte Everest",
    "118",
    "Oceano Pacífico",
    "William Shakespeare",
    "299.792.458 metros por segundo",
    "Neil Armstrong",
    "Augusto",
    "Deserto do Saara",
    "1",
    "Thomas Edison",
    "China"
]

# Exemplo de acesso às perguntas e respostas
print("Pergunta 1:", perguntas[0])
print("Resposta 1:", respostas[0])


janela = Tk()
janela.geometry("400x350+540+360")

txt = Text(height=10, width=61, background="white")
txt.grid(row=0,column=0)
txt.insert(END,"eu disse: qualquer coisa")
txt.configure


txt_send = Text(height=3, width=61, background="white")
txt_send.grid(row=0,column=0)

txt_send = Text(height=2, width=2, background="white")
txt_send.grid(row=3,column=0)

btn_send = Button(height=2, width=61, background="white", text="enviar", fg="blue", command= lambda : enviar())
btn_send.grid(row=3,column=0)


def enviar():
    txt.configure(state=NORMAL)
    txt.insert(END,"eu disse: " + txt_send.get('1.0',END) + "\n")
    txt_send.delete('1.0',END)
    txt.configure(state=DISABLED)

def resposta():
    txt.configure(state=NORMAL)
    txt.insert(END,)

    janela.mainloop()


janela.mainloop()
